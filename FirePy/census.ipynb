# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from config import gkey

# %%
fire_census_df = pd.read_csv('data/fire_census.csv')
fire_census_df.head(2)
# Out:
#          Lat        Lng  TOTAL LOSS  PERCENTAGE LOSS   Latitude  Longitude  \
# 0  32.732107 -96.814783        5000             3.01  32.732076 -96.814820
# 1  32.894248 -96.857108       10000             1.87  32.894224 -96.857101
#
#    Accuracy Score Accuracy Type   Number          Street  ...  \
# 0             1.0       rooftop   1325.0  S Marsalis Ave  ...
# 1             1.0       rooftop  10728.0      Lathrop Dr  ...
#
#    Census Block Group  Full FIPS (block) Full FIPS (tract)  \
# 0                   2    481130054002017       48113005400
# 1                   2    481130097022004       48113009702
#
#   Metro/Micro Statistical Area Name Metro/Micro Statistical Area Code  \
# 0   Dallas-Fort Worth-Arlington, TX                             19100
# 1   Dallas-Fort Worth-Arlington, TX                             19100
#
#    Metro/Micro Statistical Area Type Combined Statistical Area Name  \
# 0                       metropolitan       Dallas-Fort Worth, TX-OK
# ...

# %%
print(fire_census_df.columns)
# Out:
# Index(['Lat', 'Lng', 'TOTAL LOSS', 'PERCENTAGE LOSS', 'Latitude', 'Longitude',
#        'Accuracy Score', 'Accuracy Type', 'Number', 'Street', 'Unit Type',
#        'Unit Number', 'City', 'State', 'County', 'Zip', 'Country', 'Source',
#        'ACS Economics/Number of households/Total/Value',
#        'ACS Economics/Number of households/Total/Margin of error',
#        'ACS Economics/Median household income/Total/Value',
#        'ACS Economics/Median household income/Total/Margin of error',
#        'ACS Economics/Household income/Less than $10,000/Value',
#        'ACS Economics/Household income/Less than $10,000/Margin of error',
#        'ACS Economics/Household income/Less than $10,000/Percentage',
#        'ACS Economics/Household income/$10,000 to $14,999/Value',
#        'ACS Economics/Household income/$10,000 to $14,999/Margin of error',
#        'ACS Economics/Household income/$10,000 to $14,999/Percentage',
# ...

# %%
filter_example = fire_census_df.filter(like="Percentage")
filter_example.head()
# Out:
#    ACS Economics/Household income/Less than $10,000/Percentage  \
# 0                                              0.127
# 1                                              0.026
# 2                                              0.139
# 3                                              0.114
# 4                                              0.036
#
#    ACS Economics/Household income/$10,000 to $14,999/Percentage  \
# 0                                              0.090
# 1                                              0.009
# 2                                              0.056
# 3                                              0.000
# 4                                              0.112
#
#    ACS Economics/Household income/$15,000 to $19,999/Percentage  \
# 0                                              0.122
# 1                                              0.013
# 2                                              0.085
# 3                                              0.000
# ...
